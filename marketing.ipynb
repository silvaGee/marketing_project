# %%
import pandas as pd
import numpy as np

df = pd.read_csv("marketing_data.csv")
df.head()
# Out:
#       ID  Year_Birth   Education Marital_Status      Income   Kidhome  \
# 0   1826        1970  Graduation       Divorced  $84,835.00         0
# 1      1        1961  Graduation         Single  $57,091.00         0
# 2  10476        1958  Graduation        Married  $67,267.00         0
# 3   1386        1967  Graduation       Together  $32,474.00         1
# 4   5371        1989  Graduation         Single  $21,474.00         1
#
#    Teenhome Dt_Customer  Recency  MntWines  ...  NumStorePurchases  \
# 0         0     6/16/14        0       189  ...                  6
# 1         0     6/15/14        0       464  ...                  7
# 2         1     5/13/14        0       134  ...                  5
# 3         1     5/11/14        0        10  ...                  2
# 4         0      4/8/14        0         6  ...                  2
#
#    NumWebVisitsMonth  AcceptedCmp3  AcceptedCmp4  AcceptedCmp5  AcceptedCmp1  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2240 entries, 0 to 2239
# Data columns (total 28 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   2240 non-null   int64
#  1   Year_Birth           2240 non-null   int64
#  2   Education            2240 non-null   object
#  3   Marital_Status       2240 non-null   object
#  4    Income              2216 non-null   object
#  5   Kidhome              2240 non-null   int64
#  6   Teenhome             2240 non-null   int64
#  7   Dt_Customer          2240 non-null   object
#  8   Recency              2240 non-null   int64
#  9   MntWines             2240 non-null   int64
#  10  MntFruits            2240 non-null   int64
#  11  MntMeatProducts      2240 non-null   int64
#  12  MntFishProducts      2240 non-null   int64
#  13  MntSweetProducts     2240 non-null   int64
#  14  MntGoldProds         2240 non-null   int64
# ...

# %%
df.describe()
# Out:
#                  ID   Year_Birth      Kidhome     Teenhome      Recency  \
# count   2240.000000  2240.000000  2240.000000  2240.000000  2240.000000
# mean    5592.159821  1968.805804     0.444196     0.506250    49.109375
# std     3246.662198    11.984069     0.538398     0.544538    28.962453
# min        0.000000  1893.000000     0.000000     0.000000     0.000000
# 25%     2828.250000  1959.000000     0.000000     0.000000    24.000000
# 50%     5458.500000  1970.000000     0.000000     0.000000    49.000000
# 75%     8427.750000  1977.000000     1.000000     1.000000    74.000000
# max    11191.000000  1996.000000     2.000000     2.000000    99.000000
#
#           MntWines    MntFruits  MntMeatProducts  MntFishProducts  \
# count  2240.000000  2240.000000      2240.000000      2240.000000
# mean    303.935714    26.302232       166.950000        37.525446
# std     336.597393    39.773434       225.715373        54.628979
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isna().sum()
# Out:
# ID                      0
# Year_Birth              0
# Education               0
# Marital_Status          0
#  Income                24
# Kidhome                 0
# Teenhome                0
# Dt_Customer             0
# Recency                 0
# MntWines                0
# MntFruits               0
# MntMeatProducts         0
# MntFishProducts         0
# MntSweetProducts        0
# MntGoldProds            0
# NumDealsPurchases       0
# NumWebPurchases         0
# NumCatalogPurchases     0
# NumStorePurchases       0
# NumWebVisitsMonth       0
# AcceptedCmp3            0
# AcceptedCmp4            0
# AcceptedCmp5            0
# AcceptedCmp1            0
# AcceptedCmp2            0
# Response                0
# Complain                0
# Country                 0
# dtype: int64

# %%
df.drop("ID", axis=1, inplace=True)

# %%
df.head()
# Out:
#    Year_Birth   Education Marital_Status      Income   Kidhome  Teenhome  \
# 0        1970  Graduation       Divorced  $84,835.00         0         0
# 1        1961  Graduation         Single  $57,091.00         0         0
# 2        1958  Graduation        Married  $67,267.00         0         1
# 3        1967  Graduation       Together  $32,474.00         1         1
# 4        1989  Graduation         Single  $21,474.00         1         0
#
#   Dt_Customer  Recency  MntWines  MntFruits  ...  NumStorePurchases  \
# 0     6/16/14        0       189        104  ...                  6
# 1     6/15/14        0       464          5  ...                  7
# 2     5/13/14        0       134         11  ...                  5
# 3     5/11/14        0        10          0  ...                  2
# 4      4/8/14        0         6         16  ...                  2
#
#    NumWebVisitsMonth  AcceptedCmp3  AcceptedCmp4  AcceptedCmp5  AcceptedCmp1  \
# ...

# %%
df.rename(columns={' Income ':'Income', 'Response':'AcceptedCmp6'}, inplace=True)
df.head()
# Out:
#    Year_Birth   Education Marital_Status       Income  Kidhome  Teenhome  \
# 0        1970  Graduation       Divorced  $84,835.00         0         0
# 1        1961  Graduation         Single  $57,091.00         0         0
# 2        1958  Graduation        Married  $67,267.00         0         1
# 3        1967  Graduation       Together  $32,474.00         1         1
# 4        1989  Graduation         Single  $21,474.00         1         0
#
#   Dt_Customer  Recency  MntWines  MntFruits  ...  NumStorePurchases  \
# 0     6/16/14        0       189        104  ...                  6
# 1     6/15/14        0       464          5  ...                  7
# 2     5/13/14        0       134         11  ...                  5
# 3     5/11/14        0        10          0  ...                  2
# 4      4/8/14        0         6         16  ...                  2
#
#    NumWebVisitsMonth  AcceptedCmp3  AcceptedCmp4  AcceptedCmp5  AcceptedCmp1  \
# ...

# %%
df['Income'] = df['Income'].str.replace('[$,]', '', regex=True).astype(float)
df
# Out:
#       Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 0           1970  Graduation       Divorced  84835.0        0         0
# 1           1961  Graduation         Single  57091.0        0         0
# 2           1958  Graduation        Married  67267.0        0         1
# 3           1967  Graduation       Together  32474.0        1         1
# 4           1989  Graduation         Single  21474.0        1         0
# ...          ...         ...            ...      ...      ...       ...
# 2235        1976         PhD       Divorced  66476.0        0         1
# 2236        1977    2n Cycle        Married  31056.0        1         0
# 2237        1976  Graduation       Divorced  46310.0        1         0
# 2238        1978  Graduation        Married  65819.0        0         0
# 2239        1969         PhD        Married  94871.0        0         2
#
#      Dt_Customer  Recency  MntWines  MntFruits  ...  NumStorePurchases  \
# ...

# %%
missing_income = df[df["Income"].isna()]
missing_income
# Out:
#       Year_Birth   Education Marital_Status  Income  Kidhome  Teenhome  \
# 134         1957         PhD        Married     NaN        2         1
# 262         1983  Graduation        Married     NaN        1         0
# 394         1972         PhD       Together     NaN        1         0
# 449         1986  Graduation         Single     NaN        1         0
# 525         1961         PhD        Married     NaN        0         1
# 590         1973    2n Cycle        Married     NaN        1         0
# 899         1970      Master       Together     NaN        0         1
# 997         1957  Graduation         Single     NaN        1         1
# 1096        1964    2n Cycle         Single     NaN        1         1
# 1185        1969      Master       Together     NaN        1         1
# 1213        1978    2n Cycle       Together     NaN        0         0
# 1312        1982  Graduation         Single     NaN        1         0
# ...

# %%
mean_phd_married =(df["Education"]=="PhD") & (df["Marital_Status"]=="Married") & (df["Income"].notna())
df[mean_phd_married]
# Out:
#       Year_Birth Education Marital_Status    Income  Kidhome  Teenhome  \
# 8           1954       PhD        Married   65324.0        0         1
# 9           1954       PhD        Married   65324.0        0         1
# 23          1976       PhD        Married   49544.0        1         0
# 33          1974       PhD        Married   46374.0        0         1
# 41          1955       PhD        Married   66465.0        0         1
# ...          ...       ...            ...       ...      ...       ...
# 2196        1967       PhD        Married   77766.0        0         1
# 2201        1954       PhD        Married   70421.0        0         1
# 2204        1973       PhD        Married  157243.0        0         1
# 2205        1973       PhD        Married   54222.0        0         1
# 2239        1969       PhD        Married   94871.0        0         2
#
#      Dt_Customer  Recency  MntWines  MntFruits  ...  NumStorePurchases  \
# ...

# %%
df[mean_phd_married].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 190 entries, 8 to 2239
# Data columns (total 27 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Year_Birth           190 non-null    int64
#  1   Education            190 non-null    object
#  2   Marital_Status       190 non-null    object
#  3   Income               190 non-null    float64
#  4   Kidhome              190 non-null    int64
#  5   Teenhome             190 non-null    int64
#  6   Dt_Customer          190 non-null    object
#  7   Recency              190 non-null    int64
#  8   MntWines             190 non-null    int64
#  9   MntFruits            190 non-null    int64
#  10  MntMeatProducts      190 non-null    int64
#  11  MntFishProducts      190 non-null    int64
#  12  MntSweetProducts     190 non-null    int64
#  13  MntGoldProds         190 non-null    int64
#  14  NumDealsPurchases    190 non-null    int64
# ...

# %%
df[mean_phd_married].describe()
# Out:
#         Year_Birth         Income     Kidhome    Teenhome     Recency  \
# count   190.000000     190.000000  190.000000  190.000000  190.000000
# mean   1967.273684   58138.031579    0.410526    0.578947   50.047368
# std      11.159206   21864.261524    0.534418    0.536083   28.403049
# min    1941.000000    4023.000000    0.000000    0.000000    0.000000
# 25%    1959.000000   42494.500000    0.000000    0.000000   23.000000
# 50%    1969.000000   57081.500000    0.000000    1.000000   53.000000
# 75%    1975.000000   70079.250000    1.000000    1.000000   72.000000
# max    1990.000000  160803.000000    2.000000    2.000000   99.000000
#
#           MntWines   MntFruits  MntMeatProducts  MntFishProducts  \
# count   190.000000  190.000000       190.000000       190.000000
# mean    432.005263   21.852632       186.847368        26.989474
# std     414.968100   32.858996       263.679746        42.171104
# min       2.000000    0.000000         1.000000         0.000000
# ...

# %%
df[mean_phd_married]["Income"].mean()
# Out:
# np.float64(58138.03157894737)

# %%
# for index, row_series in df.iterrows() - to iterate over rows
#missing_income = variable for na values in income column
#go through missing income rows and impute the values based on the mean of the same edu level and marital status
#mean_phd_married =(df["Education"]=="PhD") & (df["Marital_Status"]=="Married") & (df["Income"].notna())

for index, row_series in missing_income.iterrows():
    mean_income = (df["Education"]==row_series["Education"]) & (df["Marital_Status"]==row_series["Marital_Status"]) & (df["Income"].notna())
    df.loc[index, "Income"] = df[mean_income]["Income"].mean()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2240 entries, 0 to 2239
# Data columns (total 27 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Year_Birth           2240 non-null   int64
#  1   Education            2240 non-null   object
#  2   Marital_Status       2240 non-null   object
#  3   Income               2240 non-null   float64
#  4   Kidhome              2240 non-null   int64
#  5   Teenhome             2240 non-null   int64
#  6   Dt_Customer          2240 non-null   object
#  7   Recency              2240 non-null   int64
#  8   MntWines             2240 non-null   int64
#  9   MntFruits            2240 non-null   int64
#  10  MntMeatProducts      2240 non-null   int64
#  11  MntFishProducts      2240 non-null   int64
#  12  MntSweetProducts     2240 non-null   int64
#  13  MntGoldProds         2240 non-null   int64
#  14  NumDealsPurchases    2240 non-null   int64
# ...

# %%
#show labels for Marital Status
df["Marital_Status"].value_counts()
# Out:
# Marital_Status
# Married     864
# Together    580
# Single      480
# Divorced    232
# Widow        77
# Alone         3
# YOLO          2
# Absurd        2
# Name: count, dtype: int64

# %%
#Dropping row with Alone, YOLO, and Absurd marital status because they are unclear and data is less than 5% of all data
df.drop(df.loc[df["Marital_Status"] == "YOLO"].index, inplace=True)
df["Marital_Status"].value_counts()
# Out:
# Marital_Status
# Married     864
# Together    580
# Single      480
# Divorced    232
# Widow        77
# Alone         3
# Absurd        2
# Name: count, dtype: int64

# %%
df.drop(df.loc[df["Marital_Status"] == "Alone"].index, inplace=True)
df["Marital_Status"].value_counts()
# Out:
# Marital_Status
# Married     864
# Together    580
# Single      480
# Divorced    232
# Widow        77
# Absurd        2
# Name: count, dtype: int64

# %%
df.drop(df.loc[df["Marital_Status"] == "Absurd"].index, inplace=True)
df["Marital_Status"].value_counts()
# Out:
# Marital_Status
# Married     864
# Together    580
# Single      480
# Divorced    232
# Widow        77
# Name: count, dtype: int64

# %%
# data = {'Size': ['Small', 'Medium', 'Large', 'Medium', 'Small']}
# df = pd.DataFrame(data)

# # Define the ordered categories
# ordered_categories = pd.CategoricalDtype(categories=['Small', 'Medium', 'Large'], ordered=True)

# # Convert the column to ordered categorical
# df['Size_Ordered'] = df['Size'].astype(ordered_categories)

# # Access the category codes (numerical representation)
# df['Encoded_Size'] = df['Size_Ordered'].cat.codes
df["Marital_Status"] = df["Marital_Status"].astype("category")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2233 entries, 0 to 2239
# Data columns (total 27 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Year_Birth           2233 non-null   int64
#  1   Education            2233 non-null   object
#  2   Marital_Status       2233 non-null   category
#  3   Income               2233 non-null   float64
#  4   Kidhome              2233 non-null   int64
#  5   Teenhome             2233 non-null   int64
#  6   Dt_Customer          2233 non-null   object
#  7   Recency              2233 non-null   int64
#  8   MntWines             2233 non-null   int64
#  9   MntFruits            2233 non-null   int64
#  10  MntMeatProducts      2233 non-null   int64
#  11  MntFishProducts      2233 non-null   int64
#  12  MntSweetProducts     2233 non-null   int64
#  13  MntGoldProds         2233 non-null   int64
#  14  NumDealsPurchases    2233 non-null   int64
# ...

# %%
df['Education'].value_counts()
# Out:
# Education
# Graduation    1125
# PhD            483
# Master         368
# 2n Cycle       203
# Basic           54
# Name: count, dtype: int64

# %%
ordered_categories = pd.CategoricalDtype(categories=['Basic', 'Graduation', '2n Cycle', 'Master', 'PhD'], ordered=True)
df['Education'] = df['Education'].astype(ordered_categories)
df['EducationEncoded'] = df['Education'].cat.codes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2233 entries, 0 to 2239
# Data columns (total 28 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Year_Birth           2233 non-null   int64
#  1   Education            2233 non-null   category
#  2   Marital_Status       2233 non-null   category
#  3   Income               2233 non-null   float64
#  4   Kidhome              2233 non-null   int64
#  5   Teenhome             2233 non-null   int64
#  6   Dt_Customer          2233 non-null   object
#  7   Recency              2233 non-null   int64
#  8   MntWines             2233 non-null   int64
#  9   MntFruits            2233 non-null   int64
#  10  MntMeatProducts      2233 non-null   int64
#  11  MntFishProducts      2233 non-null   int64
#  12  MntSweetProducts     2233 non-null   int64
#  13  MntGoldProds         2233 non-null   int64
#  14  NumDealsPurchases    2233 non-null   int64
# ...

# %%
df.rename(columns={'Dt_Customer':'DateEnrolled', 'Recency':'DaysSincePurchase', 'Marital_Status': 'MaritalStatus', 'Year_Birth':'BirthYear'}, inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2233 entries, 0 to 2239
# Data columns (total 28 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   BirthYear            2233 non-null   int64
#  1   Education            2233 non-null   category
#  2   MaritalStatus        2233 non-null   category
#  3   Income               2233 non-null   float64
#  4   Kidhome              2233 non-null   int64
#  5   Teenhome             2233 non-null   int64
#  6   DateEnrolled         2233 non-null   object
#  7   DaysSincePurchase    2233 non-null   int64
#  8   MntWines             2233 non-null   int64
#  9   MntFruits            2233 non-null   int64
#  10  MntMeatProducts      2233 non-null   int64
#  11  MntFishProducts      2233 non-null   int64
#  12  MntSweetProducts     2233 non-null   int64
#  13  MntGoldProds         2233 non-null   int64
#  14  NumDealsPurchases    2233 non-null   int64
# ...

# %%
df.drop(df.loc[df["Country"] == "ME"].index, inplace=True)
df["Country"].value_counts()
# Out:
# Country
# SP     1095
# SA      337
# CA      263
# AUS     159
# IND     147
# GER     120
# US      109
# Name: count, dtype: int64

# %%
df["Country"] = df["Country"].astype("category")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2230 entries, 0 to 2239
# Data columns (total 28 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   BirthYear            2230 non-null   int64
#  1   Education            2230 non-null   category
#  2   MaritalStatus        2230 non-null   category
#  3   Income               2230 non-null   float64
#  4   Kidhome              2230 non-null   int64
#  5   Teenhome             2230 non-null   int64
#  6   DateEnrolled         2230 non-null   object
#  7   DaysSincePurchase    2230 non-null   int64
#  8   MntWines             2230 non-null   int64
#  9   MntFruits            2230 non-null   int64
#  10  MntMeatProducts      2230 non-null   int64
#  11  MntFishProducts      2230 non-null   int64
#  12  MntSweetProducts     2230 non-null   int64
#  13  MntGoldProds         2230 non-null   int64
#  14  NumDealsPurchases    2230 non-null   int64
# ...

# %%
df.head()
# Out:
#    BirthYear   Education MaritalStatus   Income  Kidhome  Teenhome  \
# 0       1970  Graduation      Divorced  84835.0        0         0
# 1       1961  Graduation        Single  57091.0        0         0
# 2       1958  Graduation       Married  67267.0        0         1
# 3       1967  Graduation      Together  32474.0        1         1
# 4       1989  Graduation        Single  21474.0        1         0
#
#   DateEnrolled  DaysSincePurchase  MntWines  MntFruits  ...  \
# 0      6/16/14                  0       189        104  ...
# 1      6/15/14                  0       464          5  ...
# 2      5/13/14                  0       134         11  ...
# 3      5/11/14                  0        10          0  ...
# 4       4/8/14                  0         6         16  ...
#
#    NumWebVisitsMonth  AcceptedCmp3  AcceptedCmp4  AcceptedCmp5  AcceptedCmp1  \
# 0                  1             0             0             0             0
# ...

# %%
df['DateEnrolled'] = pd.to_datetime(df['DateEnrolled'], infer_datetime_format=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2230 entries, 0 to 2239
# Data columns (total 28 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   BirthYear            2230 non-null   int64
#  1   Education            2230 non-null   category
#  2   MaritalStatus        2230 non-null   category
#  3   Income               2230 non-null   float64
#  4   Kidhome              2230 non-null   int64
#  5   Teenhome             2230 non-null   int64
#  6   DateEnrolled         2230 non-null   datetime64[ns]
#  7   DaysSincePurchase    2230 non-null   int64
#  8   MntWines             2230 non-null   int64
#  9   MntFruits            2230 non-null   int64
#  10  MntMeatProducts      2230 non-null   int64
#  11  MntFishProducts      2230 non-null   int64
#  12  MntSweetProducts     2230 non-null   int64
#  13  MntGoldProds         2230 non-null   int64
#  14  NumDealsPurchases    2230 non-null   int64
# ...

# %%
df.head()
# Out:
#    BirthYear   Education MaritalStatus   Income  Kidhome  Teenhome  \
# 0       1970  Graduation      Divorced  84835.0        0         0
# 1       1961  Graduation        Single  57091.0        0         0
# 2       1958  Graduation       Married  67267.0        0         1
# 3       1967  Graduation      Together  32474.0        1         1
# 4       1989  Graduation        Single  21474.0        1         0
#
#   DateEnrolled  DaysSincePurchase  MntWines  MntFruits  ...  \
# 0   2014-06-16                  0       189        104  ...
# 1   2014-06-15                  0       464          5  ...
# 2   2014-05-13                  0       134         11  ...
# 3   2014-05-11                  0        10          0  ...
# 4   2014-04-08                  0         6         16  ...
#
#    NumWebVisitsMonth  AcceptedCmp3  AcceptedCmp4  AcceptedCmp5  AcceptedCmp1  \
# 0                  1             0             0             0             0
# ...

# %%
from datetime import datetime
current_year = datetime.now().year
df['Age'] = current_year - df['BirthYear']
df.head()
# Out:
#    BirthYear   Education MaritalStatus   Income  Kidhome  Teenhome  \
# 0       1970  Graduation      Divorced  84835.0        0         0
# 1       1961  Graduation        Single  57091.0        0         0
# 2       1958  Graduation       Married  67267.0        0         1
# 3       1967  Graduation      Together  32474.0        1         1
# 4       1989  Graduation        Single  21474.0        1         0
#
#   DateEnrolled  DaysSincePurchase  MntWines  MntFruits  ...  AcceptedCmp3  \
# 0   2014-06-16                  0       189        104  ...             0
# 1   2014-06-15                  0       464          5  ...             0
# 2   2014-05-13                  0       134         11  ...             0
# 3   2014-05-11                  0        10          0  ...             0
# 4   2014-04-08                  0         6         16  ...             1
#
#    AcceptedCmp4  AcceptedCmp5  AcceptedCmp1  AcceptedCmp2  AcceptedCmp6  \
# ...

# %%
df.drop('BirthYear', axis=1, inplace=True)
df.head()
# Out:
#     Education MaritalStatus   Income  Kidhome  Teenhome DateEnrolled  \
# 0  Graduation      Divorced  84835.0        0         0   2014-06-16
# 1  Graduation        Single  57091.0        0         0   2014-06-15
# 2  Graduation       Married  67267.0        0         1   2014-05-13
# 3  Graduation      Together  32474.0        1         1   2014-05-11
# 4  Graduation        Single  21474.0        1         0   2014-04-08
#
#    DaysSincePurchase  MntWines  MntFruits  MntMeatProducts  ...  AcceptedCmp3  \
# 0                  0       189        104              379  ...             0
# 1                  0       464          5               64  ...             0
# 2                  0       134         11               59  ...             0
# 3                  0        10          0                1  ...             0
# 4                  0         6         16               24  ...             1
#
#    AcceptedCmp4  AcceptedCmp5  AcceptedCmp1  AcceptedCmp2  AcceptedCmp6  \
# ...

# %%
#Total # of children
df['TotalNumChildren'] = df['Kidhome'] + df['Teenhome']
df.head()
# Out:
#     Education MaritalStatus   Income  Kidhome  Teenhome DateEnrolled  \
# 0  Graduation      Divorced  84835.0        0         0   2014-06-16
# 1  Graduation        Single  57091.0        0         0   2014-06-15
# 2  Graduation       Married  67267.0        0         1   2014-05-13
# 3  Graduation      Together  32474.0        1         1   2014-05-11
# 4  Graduation        Single  21474.0        1         0   2014-04-08
#
#    DaysSincePurchase  MntWines  MntFruits  MntMeatProducts  ...  AcceptedCmp4  \
# 0                  0       189        104              379  ...             0
# 1                  0       464          5               64  ...             0
# 2                  0       134         11               59  ...             0
# 3                  0        10          0                1  ...             0
# 4                  0         6         16               24  ...             0
#
#    AcceptedCmp5  AcceptedCmp1  AcceptedCmp2  AcceptedCmp6  Complain  Country  \
# ...

# %%
#Total Spent
df['TotalSpent'] = df['MntWines'] + df['MntFruits'] + df['MntMeatProducts'] + df['MntFishProducts'] + df['MntSweetProducts'] + df['MntGoldProds']
df.head()
# Out:
#     Education MaritalStatus   Income  Kidhome  Teenhome DateEnrolled  \
# 0  Graduation      Divorced  84835.0        0         0   2014-06-16
# 1  Graduation        Single  57091.0        0         0   2014-06-15
# 2  Graduation       Married  67267.0        0         1   2014-05-13
# 3  Graduation      Together  32474.0        1         1   2014-05-11
# 4  Graduation        Single  21474.0        1         0   2014-04-08
#
#    DaysSincePurchase  MntWines  MntFruits  MntMeatProducts  ...  AcceptedCmp5  \
# 0                  0       189        104              379  ...             0
# 1                  0       464          5               64  ...             0
# 2                  0       134         11               59  ...             0
# 3                  0        10          0                1  ...             0
# 4                  0         6         16               24  ...             0
#
#    AcceptedCmp1  AcceptedCmp2  AcceptedCmp6  Complain  Country  \
# ...

# %%
df['TotalPurchases'] = df['NumWebPurchases'] + df['NumCatalogPurchases'] + df['NumStorePurchases']
df.head()
# Out:
#     Education MaritalStatus   Income  Kidhome  Teenhome DateEnrolled  \
# 0  Graduation      Divorced  84835.0        0         0   2014-06-16
# 1  Graduation        Single  57091.0        0         0   2014-06-15
# 2  Graduation       Married  67267.0        0         1   2014-05-13
# 3  Graduation      Together  32474.0        1         1   2014-05-11
# 4  Graduation        Single  21474.0        1         0   2014-04-08
#
#    DaysSincePurchase  MntWines  MntFruits  MntMeatProducts  ...  AcceptedCmp1  \
# 0                  0       189        104              379  ...             0
# 1                  0       464          5               64  ...             0
# 2                  0       134         11               59  ...             0
# 3                  0        10          0                1  ...             0
# 4                  0         6         16               24  ...             0
#
#    AcceptedCmp2  AcceptedCmp6  Complain  Country  EducationEncoded  Age  \
# ...

# %%
from matplotlib import pyplot as plt
import seaborn as sns
#Check for outliers
features = ["Income", "TotalSpent", "TotalPurchases","TotalNumChildren", "Age"
]
plt.figure(figsize=(20, 15))
for i, feature in enumerate(features, 1):
    plt.subplot(3, 2, i)
    sns.boxplot(x=df[feature])
plt.show()

# %%
#Examine outliers
income_outliers = 200000
spent_outliers = 2000
filtered = df[df["Income"] > income_outliers]
filtered
# Out:
#       Education MaritalStatus    Income  Kidhome  Teenhome DateEnrolled  \
# 527  Graduation      Together  666666.0        1         0   2013-06-02
#
#      DaysSincePurchase  MntWines  MntFruits  MntMeatProducts  ...  \
# 527                 23         9         14               18  ...
#
#      AcceptedCmp1  AcceptedCmp2  AcceptedCmp6  Complain  Country  \
# 527             0             0             0         0       SA
#
#      EducationEncoded  Age  TotalNumChildren  TotalSpent  TotalPurchases
# 527                 1   48                 1          62               7
#
# [1 rows x 31 columns]

# %%
df.drop(df.loc[df["Income"] > income_outliers].index, inplace=True)

# %%
age_outlier = 90
df.drop(df.loc[df["Age"] > age_outlier ].index, inplace=True)

# %%
#Check for outliers
features = ["Income", "Age"
]
plt.figure(figsize=(20, 15))
for i, feature in enumerate(features, 1):
    plt.subplot(3, 2, i)
    sns.boxplot(x=df[feature])
plt.show()

# %%
df["TotalNumChildren"].value_counts()
# Out:
# TotalNumChildren
# 1    1120
# 0     634
# 2     419
# 3      53
# Name: count, dtype: int64

# %%
#explore features to identify patterns
numeric_df = df.select_dtypes(include=['number'])
matrix = numeric_df.corr()
plt.figure(figsize=(15, 10))
sns.heatmap(matrix, annot=True)
plt.title('Correlation Matrix of all features')
plt.show()

# %%
#Closely Examine highly correlated features
include_features = ['Income', 'Kidhome','Teenhome', 'MntWines','MntFruits',
                    'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts', 'MntGoldProds',
                    'NumDealsPurchases', 'NumWebPurchases', 'NumCatalogPurchases', 'NumStorePurchases',
                    'NumWebVisitsMonth','TotalNumChildren', 'TotalSpent', 'TotalPurchases']
matrix = df[include_features].corr()
plt.figure(figsize=(15, 10))
sns.heatmap(matrix, annot=True)
plt.title('Correlation Matrix of correlated features')
plt.show()
print(matrix)
# Out:
#                        Income   Kidhome  Teenhome  MntWines  MntFruits  \
# Income               1.000000 -0.509980  0.035841  0.686340   0.504916
# Kidhome             -0.509980  1.000000 -0.035568 -0.496052  -0.372958
# Teenhome             0.035841 -0.035568  1.000000  0.004143  -0.174576
# MntWines             0.686340 -0.496052  0.004143  1.000000   0.389614
# MntFruits            0.504916 -0.372958 -0.174576  0.389614   1.000000
# MntMeatProducts      0.683466 -0.436752 -0.260321  0.562844   0.542739
# MntFishProducts      0.518396 -0.387170 -0.201039  0.401234   0.594923
# MntSweetProducts     0.518330 -0.370795 -0.161761  0.386183   0.567618
# MntGoldProds         0.382101 -0.348637 -0.017136  0.387538   0.388627
# NumDealsPurchases   -0.106039  0.222243  0.387783  0.011143  -0.130706
# NumWebPurchases      0.451845 -0.362960  0.154456  0.542960   0.299882
# NumCatalogPurchases  0.693550 -0.501851 -0.109144  0.635436   0.486633
# ...

# %% [markdown]
# Show histograms of data to examine distributions of data

# %%
# display histogram of different ages

# plt.figure(figsize=(15, 10))
df.hist(column='Age', figsize=(10, 8), bins=50)
plt.title('Graph of ages')
plt.xlabel('Range of ages')
plt.ylabel('Number of people')
plt.show()

# %%
matrix_features = ['Age', 'NumWebPurchases', 'NumCatalogPurchases', 'NumStorePurchases', 'NumWebVisitsMonth']

matrix = df[matrix_features].corr()
plt.figure(figsize=(10, 10))
sns.heatmap(matrix, annot=True)
plt.title('Correlation Matrix of age vs. shopping preference')
plt.show()
print(matrix)
# Out:
#                           Age  NumWebPurchases  NumCatalogPurchases  \
# Age                  1.000000         0.152796             0.127885
# NumWebPurchases      0.152796         1.000000             0.380259
# NumCatalogPurchases  0.127885         0.380259             1.000000
# NumStorePurchases    0.138924         0.503537             0.519508
# NumWebVisitsMonth   -0.121091        -0.059390            -0.519715
#
#                      NumStorePurchases  NumWebVisitsMonth
# Age                           0.138924          -0.121091
# NumWebPurchases               0.503537          -0.059390
# NumCatalogPurchases           0.519508          -0.519715
# NumStorePurchases             1.000000          -0.432003
# NumWebVisitsMonth            -0.432003           1.000000

# %% [markdown]
# This correlation matrix doesn't show any relation between age and store preference but we need to look at other graphs to determine if this is truly the case.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2226 entries, 0 to 2239
# Data columns (total 31 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Education            2226 non-null   category
#  1   MaritalStatus        2226 non-null   category
#  2   Income               2226 non-null   float64
#  3   Kidhome              2226 non-null   int64
#  4   Teenhome             2226 non-null   int64
#  5   DateEnrolled         2226 non-null   datetime64[ns]
#  6   DaysSincePurchase    2226 non-null   int64
#  7   MntWines             2226 non-null   int64
#  8   MntFruits            2226 non-null   int64
#  9   MntMeatProducts      2226 non-null   int64
#  10  MntFishProducts      2226 non-null   int64
#  11  MntSweetProducts     2226 non-null   int64
#  12  MntGoldProds         2226 non-null   int64
#  13  NumDealsPurchases    2226 non-null   int64
#  14  NumWebPurchases      2226 non-null   int64
# ...

# %%
age_grouping = df.groupby('Age').agg(
    # catalog_purchases=('NumCatalogPurchases', 'sum'),
    store_purchases=('NumStorePurchases', 'sum'),
    mean_store_purchases=('NumStorePurchases', 'mean'),
    web_purchases=('NumWebPurchases', 'sum'),
    mean_web_purchases=('NumWebPurchases', 'mean'),
    # total_purchases=('TotalPurchases', 'sum'),
    )

plt.figure(figsize=(15, 8))
sns.barplot(data=age_grouping, x=age_grouping.index, y='mean_web_purchases')
plt.xticks(rotation=75)
plt.title('Age vs how many web purchases they made on average')
plt.ylabel('Number of Web Purchases')
plt.xlabel('Age')
plt.tight_layout()
plt.show()

age_grouping[['web_purchases', 'mean_web_purchases', 'store_purchases', 'mean_store_purchases']]
# Out:
#      web_purchases  mean_web_purchases  store_purchases  mean_store_purchases
# Age
# 29               4            2.000000                5              2.500000
# 30              14            2.800000               36              7.200000
# 31              15            5.000000               28              9.333333
# 32              12            4.000000               18              6.000000
# 33              41            3.153846               67              5.153846
# 34              61            4.066667              102              6.800000
# 35              62            3.444444               84              4.666667
# 36              85            2.833333              175              5.833333
# 37              96            3.428571              164              5.857143
# 38              90            3.333333              163              6.037037
# 39             157            3.738095              199              4.738095
# ...

# %%
group_by_children = df.groupby('TotalNumChildren').agg(
    catalog_purchases=('NumCatalogPurchases', 'sum'),
    store_purchases=('NumStorePurchases', 'sum'),
    mean_store_purchases=('NumStorePurchases', 'mean'),
    web_purchases=('NumWebPurchases', 'sum'),
    mean_web_purchases=('NumWebPurchases', 'mean'),
    )

plt.figure(figsize=(15, 8))
sns.barplot(data=group_by_children, x=group_by_children.index, y='mean_web_purchases')
plt.xticks(rotation=75)
plt.title('Number of children vs how many web purchases they made')
plt.ylabel('Mean of Web Purchases')
plt.xlabel('Number of children')
plt.tight_layout()
plt.show()

group_by_children[['web_purchases', 'mean_web_purchases', 'store_purchases', 'mean_store_purchases']]
# Out:
#                   web_purchases  mean_web_purchases  store_purchases  \
# TotalNumChildren
# 0                          2786            4.394322             4614
# 1                          4799            4.284821             6272
# 2                          1349            3.219570             1807
# 3                           152            2.867925              210
#
#                   mean_store_purchases
# TotalNumChildren
# 0                             7.277603
# 1                             5.600000
# 2                             4.312649
# 3                             3.962264

# %%
age_vs_children = df.groupby('Age').agg(
    mean_num_children=('TotalNumChildren', 'mean'),
)

plt.figure(figsize=(15, 8))
sns.barplot(data=age_vs_children, x=age_vs_children.index, y='mean_num_children')
plt.title('Age vs how many children they have on average')
plt.ylabel('Number of Children')
plt.xlabel('Age')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(18, 10))
for children in df['TotalNumChildren'].unique():
    subset = df[df['TotalNumChildren'] == children]
    plt.scatter(subset['Age'], subset['NumWebPurchases'], s=100, label=f'Children: {children}')
plt.xlabel('Age')
plt.ylabel('Number of web purchases')
plt.title('Scatter plot Age vs Purchases vs Children at home')
# plt.colorbar('scatter', label='Number of Children')
plt.legend(title='Children at home')
plt.show()

mean_purchases_by_child = df.groupby('TotalNumChildren', as_index=False).agg({'NumWebPurchases': 'mean', 'Age': 'mean'})

# %%
import plotly.express as px
import plotly.graph_objects as go
fig = px.scatter_3d(df, x='Age', y='TotalNumChildren', z='NumWebPurchases')
fig.update_layout(
    width=800,   # width in pixels
    height=600   # height in pixels
)
fig.show()

# %% [markdown]
# According to this graph, people aged 50 and above were more likely to have 3 children at home, while younger people were more likely to have 2 or fewer children at home.

# %%
import plotly.express as px
import plotly.graph_objects as go
fig = px.scatter_3d(df, x='Age', y='TotalNumChildren', z='TotalSpent')
fig.update_layout(
    width=800,   # width in pixels
    height=600   # height in pixels
)
fig.show()

# %% [markdown]
# According to this plot, as the number of children at home increased, the total amount spent decreased for all age categories.

# %%
fig = px.scatter_3d(df, x='MntFruits', y='TotalNumChildren', z='Age')
fig.update_layout(
    width=800,   # width in pixels
    height=600   # height in pixels
)
fig.show()

# %% [markdown]
# The more children at home, the less spent on fruit, which seems counterintuitive.

# %%
#                        Income   Kidhome  Teenhome  MntWines  MntFruits  \
# Income               1.000000 -0.509980  0.035841  0.686340   0.504916
# Kidhome             -0.509980  1.000000 -0.035568 -0.496052  -0.372958
# Teenhome             0.035841 -0.035568  1.000000  0.004143  -0.174576
# MntWines             0.686340 -0.496052  0.004143  1.000000   0.389614
# MntFruits            0.504916 -0.372958 -0.174576  0.389614   1.000000
# MntMeatProducts      0.683466 -0.436752 -0.260321  0.562844   0.542739
# MntFishProducts      0.518396 -0.387170 -0.201039  0.401234   0.594923
# MntSweetProducts     0.518330 -0.370795 -0.161761  0.386183   0.567618
# MntGoldProds         0.382101 -0.348637 -0.017136  0.387538   0.388627
# NumDealsPurchases   -0.106039  0.222243  0.387783  0.011143  -0.130706
# NumWebPurchases      0.451845 -0.362960  0.154456  0.542960   0.299882
# NumCatalogPurchases  0.693550 -0.501851 -0.109144  0.635436   0.486633
# NumStorePurchases    0.628779 -0.500234  0.049994  0.642181   0.463539
# NumWebVisitsMonth   -0.646675  0.449129  0.131319 -0.322456  -0.416155
# TotalNumChildren    -0.339175  0.690208  0.698604 -0.352154  -0.393429
# TotalSpent           0.788802 -0.556289 -0.137555  0.892214   0.613590
# TotalPurchases       0.738875 -0.568938  0.037796  0.756449   0.521923

# %%
fig = px.scatter_3d(df, x='MntWines', y='TotalNumChildren', z='Age')
fig.update_layout(
    width=800,   # width in pixels
    height=600   # height in pixels
)
fig.show()

# %% [markdown]
# The more children at home, the less spent on wine.

# %%
fig = px.scatter_3d(df, x='MntMeatProducts', y='TotalNumChildren', z='Age')
fig.update_layout(
    width=800,   # width in pixels
    height=600   # height in pixels
)
fig.show()

# %% [markdown]
# The more children at home, the less spent on meat.  People overall spend less on meat than wine.

# %%
fig = px.scatter_3d(df, x='MntFishProducts', y='TotalNumChildren', z='Age')
fig.update_layout(
    width=800,   # width in pixels
    height=600   # height in pixels
)
fig.show()

# %% [markdown]
# The more chilren at home, the less spent on fish products.

# %%
fig = px.scatter_3d(df, x='MntSweetProducts', y='TotalNumChildren', z='Age')
fig.update_layout(
    width=800,   # width in pixels
    height=600   # height in pixels
)
fig.show()

# %% [markdown]
# The more children at home, the less spent on sweet products.  In general, people with more children, spend less, while people with no children are spending a lot more.

# %%
fig = px.scatter_3d(df, x='TotalSpent', y='TotalNumChildren', z='TotalPurchases')
fig.update_layout(
    width=800,   # width in pixels
    height=600   # height in pixels
)
fig.show()

# %%
fig = px.scatter_3d(df, x='Age', y='TotalNumChildren', z='NumCatalogPurchases')
fig.update_layout(
    width=800,   # width in pixels
    height=600   # height in pixels
)
fig.show()

# %%
fig = px.scatter_3d(df, x='TotalSpent', y='Kidhome', z='Teenhome')
fig.update_layout(
    width=800,   # width in pixels
    height=600   # height in pixels
)
fig.show()

# %% [markdown]
# People with 0-1 children spend the most, and people with teenagers at home spend more than people with younger children.

# %%
fig = px.scatter_3d(df, x='MntMeatProducts', y='Kidhome', z='Teenhome')
fig.update_layout(
    width=800,   # width in pixels
    height=600   # height in pixels
)
fig.show()

# %% [markdown]
# People with teenagers spend slightly more on meat than people with younger children at home

# %%
fig = px.scatter_3d(df, x='MntSweetProducts', y='Kidhome', z='Teenhome')
fig.update_layout(
    width=800,   # width in pixels
    height=600   # height in pixels
)
fig.show()

# %% [markdown]
# People with teens at home spent more on sweets than people with younger children at home.

# %%
fig = px.scatter_3d(df, x='MntWines', y='Kidhome', z='Teenhome')
fig.update_layout(
    width=800,   # width in pixels
    height=600   # height in pixels
)
fig.show()

# %% [markdown]
# People with teens at home spend a lot more on wine than people with younger children at home.

# %%
#Find out if people with children do more online shopping vs other forms
#Find out if other forms of purchases are canabalizing store purchases
matrix_features = ['TotalNumChildren', 'NumWebPurchases', 'NumCatalogPurchases', 'NumStorePurchases', 'NumWebVisitsMonth']

matrix = df[matrix_features].corr()
plt.figure(figsize=(10, 10))
sns.heatmap(matrix, annot=True)
plt.title('Correlation Matrix of Chilren at Home vs. Shopping Preference')
plt.show()
print(matrix)
# Out:
#                      TotalNumChildren  NumWebPurchases  NumCatalogPurchases  \
# TotalNumChildren             1.000000        -0.148028            -0.438334
# NumWebPurchases             -0.148028         1.000000             0.380259
# NumCatalogPurchases         -0.438334         0.380259             1.000000
# NumStorePurchases           -0.321949         0.503537             0.519508
# NumWebVisitsMonth            0.416644        -0.059390            -0.519715
#
#                      NumStorePurchases  NumWebVisitsMonth
# TotalNumChildren             -0.321949           0.416644
# NumWebPurchases               0.503537          -0.059390
# NumCatalogPurchases           0.519508          -0.519715
# NumStorePurchases             1.000000          -0.432003
# NumWebVisitsMonth            -0.432003           1.000000

# %% [markdown]
# According to the heat map, people with children at home are slightly more likely to make web purchases vs other mediums like store/catalog purchases.  If we had time series data that showed the history of each type of purchase, we could say with more certainty if there was canabalization.  However, with the current data, other forms of purchases such as catalog and web purchases do not seem to be canabalizing store purchases since they are positively correlated.  If anything, this tells us that customers that are making purchases are using multiple mediums to make purchases.

# %%
from sklearn.linear_model import LinearRegression


# Define independent and dependent variables
X = df[['NumWebPurchases', 'NumCatalogPurchases']]
y = df['NumStorePurchases']

# Fit the regression model
model = LinearRegression()
model.fit(X, y)

# Print coefficients and intercept
print("Intercept:", model.intercept_)
print("Coefficients:", model.coef_)

# Optionally, display which coefficient corresponds to which variable
for col, coef in zip(X.columns, model.coef_):
    print(f"{col}: {coef}")
# Out:
# Intercept: 2.94767831552409
# Coefficients: [0.41953888 0.42721462]
# NumWebPurchases: 0.419538884178425
# NumCatalogPurchases: 0.42721462050299014

# %%
print(X.shape)
# Out:
# (2226, 2)

# %%
print(y.shape)
# Out:
# (2226,)

# %%
import matplotlib.pyplot as plt

# Predict store purchases using the model
y_pred = model.predict(X)

# Scatter plot: Actual vs Predicted
plt.figure(figsize=(8, 6))
plt.scatter(y, y_pred, alpha=0.6)
plt.xlabel('Actual Store Purchases')
plt.ylabel('Predicted Store Purchases')
plt.title('Actual vs Predicted Store Purchases')
# Diagonal line
plt.plot([y.min(), y.max()], [y.min(), y.max()], 'r--')
plt.show()

# Residual plot
residuals = y - y_pred
plt.figure(figsize=(8, 6))
plt.scatter(y_pred, residuals, alpha=0.6)
plt.axhline(0, color='red', linestyle='--')
plt.xlabel('Predicted Store Purchases')
plt.ylabel('Residuals')
plt.title('Residuals vs Predicted Store Purchases')
plt.show()

# %%
print(y_pred.shape)
# Out:
# (2226,)

# %%
# Get feature names and corresponding coefficients
features = list(X.columns)
coefficients = model.coef_
intercept = model.intercept_

# Combine intercept and coefficients for plotting
labels = ['Intercept'] + features
values = [intercept] + list(coefficients)

# Create bar plot
plt.figure(figsize=(8, 5))
plt.bar(labels, values, color='skyblue')
plt.title('Linear Regression Coefficients and Intercept')
plt.ylabel('Value')
plt.show()

# %%
#Does the US outperform the rest of the world in total purchases by volume?
age_grouping = df.groupby('Country').agg(
    total_purchases=('TotalPurchases', 'sum'),
    ).sort_values(by='total_purchases', ascending=False)
print(age_grouping)
# Out:
#          total_purchases
# Country
# SP                 13569
# SA                  4292
# CA                  3400
# AUS                 1931
# IND                 1715
# GER                 1530
# US                  1473
# /var/folders/bx/q07kjr6511l43tpccx46fsb80000gn/T/ipykernel_68661/1726864188.py:2: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.

# %% [markdown]
# The US has the least amount of purchases out of all the countries.  Spain outperfoms the rest of the world in total purchases.

# %%
# Use appropriate visualization to help analyze the following:
# Identify the top-performing products and those with the lowest revenue.
total_fish = df["MntFishProducts"].sum()
total_meats = df["MntMeatProducts"].sum()
total_sweets = df["MntSweetProducts"].sum()
total_gold = df["MntGoldProds"].sum()
total_fruit = df["MntFruits"].sum()
total_wines = df["MntWines"].sum()
values = [total_sweets, total_fish, total_meats, total_fruit, total_gold, total_wines]
labels = ["Sweets", "Fish", "Meats", "Fruit", "Gold", "Wines"]
plt.figure(figsize=(8, 5))
plt.grid(True, lw=0.5)
bars = plt.bar(labels, values, color='skyblue')
plt.bar_label(bars, label_type='edge', padding=3)
plt.title('Sales by Category')
plt.ylabel('Total Spent')

plt.show()

# %% [markdown]
# The top-performing product is wines, followed by meats.  The product with the lowest revenue is fruit.

# %%
# Examine if there is a correlation between customers' age and the acceptance rate of the last campaign.
include_features = ['Age', 'AcceptedCmp1','AcceptedCmp2','AcceptedCmp3','AcceptedCmp4','AcceptedCmp5','AcceptedCmp6']
matrix = df[include_features].corr()
plt.figure(figsize=(10, 7))
sns.heatmap(matrix, annot=True)
plt.title('Correlation Matrix between Age and Last Campaign Accepted')
plt.show()

# %% [markdown]
# There is no correlation between age and accepting the last campaign.  In fact, there is no correlation between age and accepting any campaign.  There does seem to be a slight correlation between accepting the first campaign and the fifth campaign.

# %%
# Determine the country with the highest number of customers who accepted the last campaign.

# %%
# Analyze the educational background of customers who lodged complaints in the last two years.
